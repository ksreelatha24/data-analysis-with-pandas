# %%
# Assignment create a column to create percentage based on Math, reading and writing score
# based on percentage column take out male scored more than 50%
# based on percentage column take out male scored less than 50%
# same as above for female
# how many female candidates are there
# how many male candidates are there
# from this data find out how many students parent level educations are batchelors degree
# how many males in standard lunch
# how many males in free lunch
# how many females in standard lunch
# how many females in free lunch

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\HARI HARAN RAO\Downloads\StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#percentage
data["percentage"]= (data["math score"]+data["reading score"]+data["writing score"])/3
data["percentage"]
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: percentage, Length: 1000, dtype: float64

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#male>50
male_data=data.loc[(data["percentage"]>50)|(data["gender"]=="male")]
len(male_data)
# Out:
# 956

# %%
#female>50
female_data=data.loc[(data["percentage"]>50)|(data["gender"]=="female")]
len(female_data)
# Out:
# 935

# %%
#female<50
dat_female=data.loc[(data["percentage"]<50)|(data["gender"]=="female")]
len(dat_female)
# Out:
# 582

# %%
#male<50
male_dat=data.loc[(data["percentage"]<50)|(data["gender"]=="male")]
len(male_data)
# Out:
# 956

# %%
#len male
l1=data[data["gender"]=="male"]
l1
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %%
len(l1)
# Out:
# 482

# %%
#len female
l2=data[data["gender"]=="female"]
l2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
len(l2)
# Out:
# 518

# %%
#bachelors degree
educational_data=data.loc[data["parental level of education"]== "bachelor's degree"]
len(educational_data)
# Out:
# 118

# %%
#lunch standard female
lunch_data_f=data.loc[(data["gender"]=="female")&(data["lunch"]=="standard")]
len(lunch_data_f)
# Out:
# 329

# %%
#lunch standard male
lunch_data_male=data.loc[(data["gender"]=="male")&(data["lunch"]=="standard")]
len(lunch_data_male)
# Out:
# 316

# %%
#lunch free female
lunch_data_f_free=data.loc[(data["gender"]=="female")&(data["lunch"]=="free/reduced")]
len(lunch_data_f_free)
# Out:
# 189

# %%
#lunch free male
lunch_data_m_free=data.loc[(data["gender"]=="male")&(data["lunch"]=="free/reduced")]
len(lunch_data_m_free)
# Out:
# 166
